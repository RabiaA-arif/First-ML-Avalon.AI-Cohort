# %% [markdown]
# <a href="https://colab.research.google.com/github/RabiaA-arif/First-ML-Avalon.AI-Cohort/blob/main/test_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_tuple = (10, 20, 30)
my_it = iter(my_tuple)
print(next(my_it))
my_tuple = (40, 50, 60) # Reassigning the tuple
print(next(my_it))
# Out:
# 10
# 20

# %%
# Out:
# 5 Done
# 3 Done
# 1 Done

# %%
my_list:list = ["rabia","arif","hi","yes"]
my_list.sort(key=len)
print(my_list)
# Out:
# ['hi', 'yes', 'arif', 'rabia']

# %%
my_list:list = ["rabia","arif","hi","yes"]
my_list.sort(key=lambda my_list:my_list[-1])
print(my_list)
# Out:
# ['rabia', 'arif', 'hi', 'yes']

# %%
numbers:list = [1,2,3,4,5]
numbers.reverse()
print(numbers)
# Out:
# [5, 4, 3, 2, 1]

# %%
x = [1, 2, [3, 4]]
y = list(x)
x[2].append(5)
print(x == y)
print(x is y)
# Out:
# True
# False

# %%
keys = ['a', 'b', 'c']
values = [1, 2, 3]
d = {k: v*2 for k, v in zip(keys, values) if v > 1}
print(d)
# Out:
# {'b': 4, 'c': 6}

# %%
t = (1, 2, [3, 4])
try:
  t[2] += [5, 6]
except TypeError:
  print("Error")
print(t)
# Out:
# Error
# (1, 2, [3, 4, 5, 6])

# %%
L = [1, 2, 3, 4, 5]
L[1:4] = [0]
print(L)
# Out:
# [1, 0, 5]

# %%
d = {'a': 1, 'b': 2, 'c': 3}
item = d.popitem()
print(item)
print(len(d))
# Out:
# ('c', 3)
# 2

# %%
matrix = [[1, 2], [3, 4]]
flat = [num for row in matrix for num in row]
print(flat)
# Out:
# [1, 2, 3, 4]

# %%
s1 = {1, 2, 3}
s2 = {3, 4, 5}
print(s1 & s2)
print(s1 | s2)
# Out:
# {3}
# {1, 2, 3, 4, 5}

# %%
s = "a,b,c"
L = s.split(",")
print("-".join(L))
# Out:
# a-b-c

# %%
L = [3, 1, 2]
L2 = sorted(L)
L.sort(reverse=True)
print(L)
print(L2)
# Out:
# [3, 2, 1]
# [1, 2, 3]

# %%
d = {'name': 'Alice', 'age': 25}
print('Alice' in d)
print('name' in d)
# Out:
# False
# True

# %%
my_set = {[1,2,3]}
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3450/889477652.py in <cell line: 0>()
# ----> 1 my_set = {[1,2,3]}
#       2 print(my_set)
#
# TypeError: unhashable type: 'list'

# %%
multile_type = {2,2.0,"hello",(1,2,3),True,False,"a",'b'}
multile_type.add(9)
multile_type.remove('b')
print(multile_type)
# Out:
# {False, True, 2, 'hello', 'a', (1, 2, 3), 9}

# %%
a: str = "Hello! World"
b: str = "Hello! World"

print("id(a) = ", id(a))
print("id(b) = ", id(b))
# Out:
# id(a) =  134796947364208
# id(b) =  134796947367408

# %%
print("hash(a) = ", hash(a))
print("hash(b) = ", hash(b))
print("-----------")
print("hash(a)      = ",hash(a))
print("a.__hash__() = ", a.__hash__()) # __dunder__()
# Out:
# hash(a) =  7305787311092865192
# hash(b) =  7305787311092865192
# -----------
# hash(a)      =  7305787311092865192
# a.__hash__() =  7305787311092865192

# %%
# frozenset is hashable

gr1 = frozenset(['A','B','C'])
gr2 = frozenset(['D','F','G'])

# frozenset as dict key
my_dict = {gr1: "Set 1",gr2: "set 2"}
print(my_dict[gr2])
print(f"hash of gr1:{hash(gr1)}")
# Out:
# set 2
# hash of gr1:1558704566792331031

# %%
my_list: list = [1,2,3,4,5]

for index , value in enumerate(my_list):
  print(f"Index:{index},Value:{value}")
# Out:
# Index:0,Value:1
# Index:1,Value:2
# Index:2,Value:3
# Index:3,Value:4
# Index:4,Value:5
