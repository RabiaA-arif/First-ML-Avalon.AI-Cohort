# %% [markdown]
# <a href="https://colab.research.google.com/github/RabiaA-arif/First-ML-Avalon.AI-Cohort/blob/main/Built_in_Exception_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***<font color="green">Interview Questions</font>***
#
# 1. When should you catch exceptions raised by functions you call, and when should you not?
# 2. How can you know what exception classes to catch?
# 3. When you catch an exception, what should you do to "handle" it?
# 4. Why is catching all exceptions considered a bad practice, and when is it okay to do it?

# %% [markdown]
# **<font color="green">BaseException</font>**
#
#
# A class in which all other Exception derived
#
# No need to import this class
#
# Python use classes to show errors and exceptional conditions these classes called exceptions class
#
# Commonly occurring exceptions are usually defined
# in the compiler/interpreter. These are called built-in
# exceptions.

# %% [markdown]
# <font color="green"></font>

# %% [markdown]
# ### **<font color="green">Built-in Exception Table</font>**

# %% [markdown]
# |<mark style="background-color: #90ee90;">Name of Built-in Exception</mark> |  <mark style="background-color: #90ee90;">Explanation </mark> |
# | :----------- | :---------------------|
# |SyntaxError   |It is raised when there is an error in the syntax of the Python code
# |ValueError    |It is raised when a built-in method or operation receives    anargument that has the right data type but mismatched or inappropriate values
# |IOError       |It is raised when the file specified in a program statement cannot be opened
# |KeyboaredInterrupt  |It is raised when the user accidentally hits the Delete or Esc key while executing a program due to which the normal flow of the program is interrupted
# |ImportError |It is raised when the requested module definition is not found
# |EOFError   |It is raised when the end of file condition is reached without reading any data by input()
# |ZeroDivisionError |It is raised when the denominator in a division operation is zero
# |IndexError|It is raised when the index or subscript in a sequence is out of range
# |NameError|It is raised when a local or global variable name is not defined
# |IndentationError|It is raised due to incorrect indentation in the program code
# |TypeError|It is raised when an operator is supplied with a value of incorrect data type
# |OverFlowError|It is raised when the result of a calculation exceeds the maximum limit for numeric data type

# %% [markdown]
# **<font color="green">raise Statement</font>**
#
# raise exception type (argument)

# %% [markdown]
# **<font color="green"> assert Statement </font>**

# %% [markdown]
# ## **<font color="green"> Control Flow Of Exception</font>**
#
# **try:** in try block we write code in which error accur at runtime
#
# **except:** give detail about error which happen in `try` block
#
# **else:** run code when try block execute with any error
#
# **finally:** Always executes at the very end, regardless of whether an error occurred or was handled, making it perfect for cleanup tasks like closing files

# %% [markdown]
# ## **<font color="green"> Process Of Exception Handling </font>**
# ![google image](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTtm9j7NWqWmgMk7_bB71-7sUC7c-zg1T-tYhZ5VXGcZ6SAFzgYNzyAWUI&s=10)

# %%
    # accessing index
my_list: list = [1,2,3,4]
try:
  print(my_list[9])
except:
  print("Index is not range")
# Out:
# Index is not range

# %% [markdown]
# #**<font color="green">User Defined Exceptions</font>**

# %% [markdown]
# you study about heap and stack frame and other concepts these all are concepts is abstract we have believe on explanation what if my mind is not believing all these explanation and i want to see or exprience all of these things make sure trust on these things problem is that how i exprience things means how i see it

# %% [markdown]
# ###**Practice question**
#
# 1. “Every syntax error is an exception but every exception
# cannot be a syntax error.” Justify the statement.
# 2. When are the following built-in exceptions raised? Give
# examples to support your answers.
# a) ImportError
# b) IOError
# c) NameError
# d) ZeroDivisionError
# 3. What is the use of a raise statement? Write a code to
# accept two numbers and display the quotient. Appropriate
# exception should be raised if the user enters the second
# number (denominator) as zero (0).
# 4. Use assert statement in Question No. 3 to test the
# division expression in the program.
# 5. Define the following:
# a) Exception Handling
# b) Throwing an exception
# c) Catching an exception
# 6. Explain catching exceptions using try and except block.
# 7. Consider the code given below and fill in the blanks.
# print (" Learning Exceptions...")
# try:
#  num1= int(input (" Enter the first number")
#  num2=int(input("Enter the second number"))
#  quotient=(num1/num2)
#  print ("Both the numbers entered were correct")
# except _____________: # to enter only integers
#  print (" Please enter only numbers")
# except ____________: # Denominator should not be zero
#  print(" Number 2 should not be zero")
# else:
#  print(" Great .. you are a good programmer")
# ___________: # to be executed at the end
#  print(" JOB OVER... GO GET SOME REST")

# %%
def foo():
    try:
        return bar()
    except Exception as e:
        type, val, tb = sys.exc_info()
        print ("got this here", e, repr(tb))

# %%
def foo():
    try:
        return bar()
    except Exception as e:
        print ("got this here", e)

# %%
def catch():
    try:
        result = bar()
    except Exception as e:
        result = e
    return result

# %%
def reraise(tp, value, tb=None):
    if value is None:
        value = tp()
    if value.__traceback__ is not tb:
        raise value.with_traceback(tb)
    raise value

# %%
def catch():
    try:
        result = bar()
    except Exception as e:
        result = e
    try:
        return result
    finally:
        del result
def reraise(tp, value, tb=None):
    if value is None:
        value = tp()
    try:
        if value.__traceback__ is not tb:
            raise value.with_traceback(tb)
        raise value
    finally:
        del value, tb

# %% [markdown]
# ## Traceback cycle problem

# %% [markdown]
# # file handling

# %%
# file opening with specific mode
file = open("/content/file_handling/my_content.txt","w")
file.write("My name is Rabia Arif\n")
# file.close()
# Out:
# 22

# %%
file2 = open("/content/file_handling/my_file.py","a") # if file not exist it create file than open with append mode

# %%
# file = open("/content/file_handling/my_file.py","x") # "X" exclusive error if file exist this command is not work and give FileExistsError

# %%
# writeline add the list content in file
my_list = ["01\n","02\n","04\n","05\n"]
file.writelines(my_list)
file.close()

# %%
file = open("/content/file_handling/my_content.txt","r")
# file.close()

# %%
# file3 = open("/content/file_handling/my_app.txt","r") # r mode only use for read this file not exist so it give FileNotFoundError

# %%
content = file.read()
print(content)
# Out:
# My name is Rabia Arif
# 01
# 02
# 04
# 05
# 01
# 02
# 04
# 05

# %%
line = file.readline()
print(line)

# %%
file.seek(0)
# Out:
# 0

# %%
print(file.tell())
# Out:
# 0

# %%
line = file.readline()
print(line)
# Out:
# My name is Rabia Arif

# %%
file.seek(0)
# Out:
# 2

# %%
print(file.tell())
# Out:
# 2

# %%
file.seek(10) # move pointer to 10 index
line1 = file.readline()
print(line1)
# Out:
#  Rabia Arif

# %%
file.seek(0)
lines = file.readline()
for line in lines:
  print(line)
file.close()
# Out:
# M
# y
#
# n
# a
# m
# e
#
# i
# s
#
# R
# a
# b
# i
# a
#
# A
# r
# i
# f

# %%
file = open("/content/file_handling/my_content.txt","r")
for line in file:
  print(line.strip())
# Out:
# My name is Rabia Arif
# 01
# 02
# 04
# 05
# 01
# 02
# 04
# 05

# %%
# open file "with" and use try except for exception handling
try:
  with open("/content/file_handling/my_content.txt","x") as file:
    print("File is created")
except FileExistsError:
  print("File is Already Exists")
finally:
  print("Operations Complete")
# Out:
# File is Already Exists
# Operations Complete

# %%
try:
  with open("/content/file_handling/myfile.txt","x") as file:
    print(f"myfile.txt is created")
except FileExistsError:
  print("File is Already Exists")
finally:
  print("Operation is Done Successfully")
# Out:
# myfile.txt is created
# Operation is Done Successfully

# %%
try:
  with open("/content/file_handling/myfile.txt","w") as file:
    file.write("Yeah I Love Programming for my Depth of Heart\n")
    file.write("But Debugging is Also Kind of Fun for Developer\n")
    print("Data is written in file")
except:
  print("Process is unsuccessfull")
finally:
  print("Now All operations are  shut down")
file.close()
# Out:
# Data is written in file
# Now All operations are  shut down

# %%
try:
  with open("/content/file_handling/myfile.txt","r") as file: # while using "with" statement file is automatically close we dont neet to close explicitly
    content = file.read()
    print(content)
except:
  print("File is open in read only mode")
finally:
  print("All operation is done")
# Out:
# Yeah I Love Programming for my Depth of Heart
# But Debugging is Also Kind of Fun for Developer
#
# All operation is done

# %%
with open("/content/file_handling/myfile.txt","r") as file:
  for line in file:
    print(line)
# Out:
# Yeah I Love Programming for my Depth of Heart
#
# But Debugging is Also Kind of Fun for Developer

# %%
with open("/content/file_handling/my_content.txt","r") as file:
  print(file.tell())

  while True:
    content = file.read(8)
    if not content:
      print("End of File")
      break
    print(content)
# Out:
# 0
# My name
# is Rabia
#  Arif
# 01
#
# 02
# 04
# 0
# 5
# 01
# 02
#
# 04
# 05
#
# End of File

# %%
# file.seek(offset.whence)
# ofoset : number of bytes for move
# whence : where to start moving
with open("/content/file_handling/my_content.txt","rb") as file:
  file.seek(3,0) # pointer as 3 position
  print(file.tell())
  line = file.readline()
  print(line) #

  file.seek(-5,2)
  print(file.tell())
  lin1 = file.readline()
  print(lin1)
# Out:
# 3
# b'name is Rabia Arif\n'
# 41
# b'4\n'
