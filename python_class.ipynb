# %% [markdown]
# <a href="https://colab.research.google.com/github/RabiaA-arif/First-ML-Avalon.AI-Cohort/blob/main/python_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import dis

# %%
def x(a : int=100):
  return a

dis.dis(x)

# %%
import dis
# Example of integers as objects
x: int = 100
print(x.bit_length())  # Method call on an integer object

# %%
import dis
dis.dis("x.bit_lenght()")

# %% [markdown]
# #🦆Duck Typing In Python

# %% [markdown]
# ![](https://realpython.com/cdn-cgi/image/width=1920,format=auto/https://files.realpython.com/media/Duck-Typing-in-Python_Watermarked.b1b2472a1e39.jpg)

# %% [markdown]
# ## "if it walk like  and quacks like a duck,then it must be a duck"
#
# Even when non duck entity behave like a duck it is considered duck because it's emphasis on behavior
#
# ## why duck typing exist  in python ,why AI engineer use duck typing ?
#
# **Duck typing** : specific behavior of classes,methods and functions
#
# focus on behavior not type ,but what it mean behavior i am not understand it

# %% [markdown]
# ## Duck Typing is form of polymorphisim where types and class object is determined by it's behavior rather than it's explicitly inheritance from a particular class
#
# **Explicit Inheritance** intensional and visible relationship between child/subclass and parent/superclass

# %%
from os import name
class Person:
    def name(self):
        print(f"Name Of Person is : Rabia")



class Student:
    def name(self):
        print(f"We Are The Student Of Uni")



def person_info(info):
    # info.name()
    return info.name()


obj=Person()
obj1=Student()
# print(person_info(obj))
# print(person_info(obj1))
person_info(obj)
person_info(obj1)

# %% [markdown]
# #Exercise: Generating Our First Python Code

# %%
x = 10

if x > 5:
    print("x is greater than 5")
    print("This is inside the if block")
    y = x + 5
    print(f"The value of y is: {y}")

print("This is outside the if block")

# %% [markdown]
# # Practising Python Data Types

# %% [markdown]
# ![](https://www.jcchouinard.com/wp-content/uploads/2023/07/Python-Data-Types.png)

# %% [markdown]
# ## Varaible : Are the container which store data values

# %%
x :int = 10
name :str = "Rabia"
pi :float = 3.14

# %% [markdown]
# #String Interning
# string interning ek technique ha python mn jis main similar types ki multiple string ko cache main rakha jata ha and ek pointer hota ha jo sub ko reference karta ha for interpreter/compilation ki optimization ka leye
#
# String interning help for performence boost
#
# ## Internal for String Interning
#
# In CPython, the String references are stored, accessed, and managed using a Python dictionary named interned. This dictionary is lazily initialized upon the first String Intern invocation and holds the reference to all the interned String objects

# %% [markdown]
# ![](https://user-images.githubusercontent.com/4745789/102705512-d1691680-42ae-11eb-825f-1e032a7c12c5.png)

# %%
print('python' is 'python')

# %% [markdown]
# # Why is String Interning Useful
# ## Memory Efficiency : by storing one '(copy of identical)' string can reduce the memory usage
#
# ## Performence Improvement : Interned strings allow for faster comparasion

# %%
# Automatic interning identifiers

a : str ="Rabia"
b : str ="Rabia"
print(a is b) # in this 'is' check the address
#  'is' : identity comparasion : it check the both two veriable point the same memory or not
#  '==' check value not address

list_a :list =[1,1,1]
list_b : list =[1,1,1]
print(list_a is list_b) # False because they both point seperate memory address
print(list_a == list_b) # True : becaues they both have same content
list_c : list  = list_a
print(list_c is list_a) # True : because point same memory address

# %%
# Automatic Interning of Short Strings

a : str = "RabiaArif"
b : str ="RabiaArif"
print(a is b) #True : short string automatically interned

# %%
# long string
sent : str = "this_is_place_heaven_and_with_full_of_evilness_yeah"
sent1 : str = "this_is_place_heaven_and_with_full_of_evilness_yeah"
print(sent is sent1)

m = 'longer_string_that_is_not_interned'
n = 'longer_string_that_is_not_interned'
print(m is n)

# %%
# Manual String
import sys
name : str = "Rabia Arif"
name2 : str = "Rabia Arif"
print(name is name2) #False

a :str =sys.intern("Rabia Arif")
b : str = sys.intern("Rabia Arif")
print(a is b) # True

# %%
# Memory Savings with Interning
str_list = [sys.intern('repeat') for _ in range(1000)]
print(str_list[0] is str_list[999])

# %% [markdown]
# #🦕 AI Generated text
#
# ## What is string interning in Python? Which strings are interned automatically and which are not? How would you force interning, and when might that matter in production systems?
#
# Python interns compile-time string constants and strings that look like valid Python identifiers (only letters, digits, underscores). Runtime-generated strings like user input are not interned. Use `sys.intern()` to force it. Useful for memory savings when storing millions of repeated strings.
# Identifiers and string literals are interned automatically
# Strings with spaces, punctuation, or created at runtime are not
# `sys.intern('mystring')` forces interning — returns the canonical object
# Useful in NLP pipelines or large dictionaries with repeated keys

# %% [markdown]
# # 🧲 Memory Management in Python

# %%
# veriable of python store which type on memory is contigous or non contigous ?

# %% [markdown]
# # 🔭 Lesson 2 Data Types practice

# %%
# Integer type : A Whole Number

num : int =10
print(f"Interger Value is : {num} And type Of {type(num)}")

# %%
# Float Type : Number Of contain Decimal
salary : float = 12000.16
print(f"Type Of Salary {type(salary)} With value : {salary}")

# %%
# None Type : one object contain nothing
val  : int = None
print(f"Type is {type(val)} With value : {val}")

val1 : str = None
print(f"Type Of {type(val1)}")

# %%
# Integer String : Value of Integer between -5 and 256 is must be interned
# Interned means whenever two identical value of veriable created so it must reference same object means one value is stored but both veriable point same idress

############## is : Memory Identifier
num1 : int = 100
num2 : int = 100
print(num1 is num2) # true - because pointing same address
print(num1 == num2) # True - because both are equal
print(id(num1))
print(id(num2))
# both of above have same address is proff for string interning


num3 : int = 259
num4 : int =259
print(num3 is num4) # False - because interning rule apply only number which is less than 256
print(num3 == num4) # True
print(id(num3))
print(id(num4))

# %%
# Complex Number : Number which contain real and imaginary part
complx : complex = 5+3j
print(f'Type is {type(complx)} Complex Num : {complx}')
print(f"Real part is :{complx.real} And Imaginary part is {complx.imag}")

# %%
# Boolean :falsy and truthy
#falsy : 0,[],'',{},None
#truthy : non-none value,non empty string

# bool=[]
# bool=""
# bool = {}
# print(num)
# bool("rabia")

# %% [markdown]
# ## Is List Interning possible in python -> no list interning is not possible  `mutable`
# ## Why list Interning is not possible in python ? -> because interning is the `Memory optimization ` in which there must be immutable object

# %%
# List Data types

student_info : list = [23,5,'AI','Third year',4.66,4+9j]
student2_info : list = [23,5,'AI','Third year',4.66,4+9j]
print(type(student_info))
print(id(student_info))
print(id(student2_info)) # list is not interned

# %%
# Tuple Data Types : immutable ,ordered collection of items
nic : tuple = (3333333333333,'status','cast',2.76,True)
print(f"Type of object: {type(nic)} with value {nic}")
nicc : tuple = (3333333333333,'status','cast',2.76,True)
print(nic is nicc) # False

# %%
# Range : sequence of numbers
a  : range = range(9,34,3)
print(type(a),"Type : " ,"with value :",a.stop)

for i in range(4,8,2):
    print(i)

# %%
# Set : contain `unique , mutable ,unordered values`
my_num : set = {55,65,22,22,0,4}
print(f"{type(my_num)} with value {my_num}")

# %% [markdown]
# # Frozen Set
# `immutable version of set`

# %%
frozen_set : set = frozenset([2,3,3,4])
print(frozen_set)

# %%
# Dictionary Type : store value in key value pair -> maping type
my_dic : dict = {'name':'rabia','profession':'student'}
print(my_dic)

# %%
# Byte Data types -> immutable
num : bytes = 'Rabia'
print(num)

# %%
# byte array : mutable
age : bytearray = [22]
print(age)

# %% [markdown]
# # Binary Types

# %%
# to be continue from python official documentations
# " The elements in a bytes object are integers in the range 0 to 255"
# bytes is immutable array

name : bytes = b'rabia'
name2 : str = 'aimen'
print(name[2])
print(name2[2])
print(type(name))
print(list(name))
print(list(name2))

# %%
text = bytes('cant survive in hostel','utf-8')
print(text)

# %%
text_byte = "hostel".encode("utf-8")
print(text_byte)

# %%
# Byte Array
# mutable sequence of bytes
#

# %% [markdown]
# # **Operators And Operands**
# ## **content discuss**
# Unary operators `negative` , `logical NOT`
#
# **Bitwise NOT**
#
# **Binary Operators**  `Arthimatic`,`comparasion`,`logical operators`,`Assignment`
#
# **Chained comparasion operators**
#
# **Walrus operators**
#
# **identity operators**
#
# **Membership operators**

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:1100/format:webp/1*AXYHLRHKf6PbwFMm9SSCqg.jpeg)

# %%
# Operator is special symbol that perform calculation
# Operands : are the value or data in which use for calculations

# %% [markdown]
# # **Unary Operator** : work with one operand single value

# %%
# negative `-` is used to change sign
a : int = 81
b : int = - a
print('The value of b :',b)

# %%
# logical NOT 'not' is used to reverse the boolean value
a : int = 10
b : int = 99
com : bool = b > a # True
# rvese_valu  : bool = ~ com  : in latest python version we cant use negation sign directly
val   = not com
print(com)
print(val)

# %% [markdown]
# **Bitwise NOT `~`**: bitwise operatoe reverse the binary valie

# %%
num : int = 5
print(format(num ,'08b')) # displaying the binary value of '5'
num1  = ~ num
print(format(num1 & 0xFF,'08b')) # '0xFF' : In Python, 0xff is a hexadecimal literal that represents the decimal integer 255
# '08b' : 08b is a format specifier used to convert an integer into a binary string that is exactly 8 characters long

# %% [markdown]
# # **Binary Operator** : work with two operands

# %%
# Arthimatic operator : use for basic operation
num1 : int =22
num2 : int = 56
add = num1 + num2
sub = num1 - num2
mul = num1 * num2
divde = num1 / num2
floor_divide = num1 // num2 # return whole number
modls = num1 % num2 # return remainder after division
exp = num1 ** num2 # return exponnential value

# %% [markdown]
# # **comparasion operators** : compare two value and return results in boolean

# %%
# Equal to '=='
a : int = 10
b : int = 10
print(a == b)
print(a != b)

# Not Equal '!='
c : int = 12
print( c != a)

# greater than '>'
print(c > b)

# Less than '<'

print(c < b)

# Greater Than or Equal to '>='

print(c >= a)

# Less Than or Equal TO '<='

print(c <= b)

# Logical operator : used to combine the conditional statements 'and ','or'

print(a >b and c < a)

print( a == b or c <= a)

# %% [markdown]
# ## Assignment operator

# %%
# = 'assign value to veriable'
a : int = 3
print(a)

# '+=' : add and assign value
b : int = 8
a += b
print(a)

# '-=' : subtract and assign value
b : int = 8
a -= b
print(a)

# Multiply and Assign
x : int = 6
x *= 2
print(x)

# Divide and Assign
x /= 3
print(x)

# Floor Divide and Assign

x //=2
print(x)

# %% [markdown]
# # **Membership Operator** : check the value is in sequence `in` ,`not in`

# %%
num_list : list = [1,3,3,4,5,'rabia']
print('rabia' in num_list)
print (2 not in num_list)

# %% [markdown]
# # **Identity Operator** : used to compared or checked the memory locations `is`, `is not`

# %%
a : int =10
b : int =10
print(a is b)
print(a is not b)

# %% [markdown]
# # **chained Operators** : chained comparasion is used to compare multiple expressions in pyhton
#
# **Benefits of chained operator** : improve readibility , reduce redundancy ,enhance performence
#
# **Used In** : checking value in range or not ,verify multiple condition in single line ,made code more readable and concise

# %%
x : int  = 28
print(88 > x < 21)  #open form of expression is (88 < x) and (x < 21) : join by and operator that why giving us false answer
print(7 < x >21) # True

print(10 < x <=28)
print(33 > x != 33 )

# %%
def name():
    return "rabia"


print("rabiaArif" != name() != "aimen")

# %%
# a , b ,c: int = 2,3,9 # Python does not support declaring multiple variables with type hints on a single line using the standard var: type = value syntax

# %%
# a : int ; b :int ; c :int = 10,22,33 : this is also not correct way

# %%
a : int = 12 ; name : str = "rabia" ; uni : str = "quest"
print(a ,name ,uni)

# %%
x : int =10 ; y :int = 20 ;  z : int =10
print(x <y >x <z) # (x < y) and (y>x) and (x<z)

# %%
num : int = "99"  # int is just used for type hint not declaring variable as the integer
print(type(num))

# %% [markdown]
# #💝 **Gift Question For You My Dear Rabia ♥**
#
# Python is dynamically typed, but also supports type hints `PEP 484+`. Explain the difference between dynamic typing, duck typing, and structural subtyping `Protocols`. How do these interact with mypy or pyright in a production codebase?

# %% [markdown]
# #**Dynamic Type Language** : dynamic type means variable have not fixed typed ,it decide on runtime
#
# `flexibility`: any time we can assign any value without being worried of type of veriable
#
# `concisenss`not need to declare explicitly variable typed

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:1400/1*E-sQRafw0eFkb7hV5dT8sA.jpeg)

# %% [markdown]
# ![ss.png](data:image/png;base64,...)

# %% [markdown]
# # protocols and Structural Subtyping `static duck typing`
#  Structural subtyping is based on the operations that performed with object
#
#  `Protocol` : is the way to define structural subtyping in python
#
#  simple word main bolen tou protocol means ek treeqa ha jis ka through hum structural subtyping achive kar sacte han with inharitence ka use kar ka
#
#  as sa phale nominal typing jis main python inheritance ka use kar ka ek class ka methd dosri class main use karti thi
#
#  but ab hum structural subtyping ka use ka ka without explicitly inheritance ka use kar ka ek class ka method ko dosri class ka method main use kar sacte hain

# %%
from typing import Protocol
class Uni(Protocol):
  def names(self):
    pass # Protocol only defines the interface, not the implementation

class Uni1():
  def names(self):
    print("I am Uni1 and I have a names method!")

def uni_name(name : Uni):
  name.names()

uni_name(Uni1())

# %%
from typing import Protocol
class ReadBook(Protocol):
  def read(self):
    pass

def read_book(book: ReadBook):
  book.read()

# print(read_book(ReadBook()))

# %%
#isinstance() is the fuction which check the type of object
# isinstance(5,int)  # check is 5 have interger type
# isinstance('rabia',str)
isinstance('rabia',(int,float,tuple,bool))  # check the 'rabia' type from this given types if exist so return True otherwise False

# %%
a = 8  # int type
a = 'rabia'  # str type
a = {'name': 'rabia'}  # dict type
# decide when code is run

# %%
m

# %% [markdown]
# # **PEP 484 `Docstring convention`**

# %% [markdown]
# # **PEP 8 `writing style convention for python`**
#
# **Code Layout**

# %%
# Identation : use 4 space
# Space is prefered as compare to tab

def rule() -> str :
    return "python rule of identation"

# always aligned with opening delimeter
def num(num1 : int ,num2 : int,
        num3 : int ,num4 : int):
    return num1 + num2

# %%
# Maxium line lenght : 79 characters : limiting the line make it possible ,\
# to open multiple file in on window with clear look

# %%
# Should line break before or after a binary operator
#  correct way of writing

# In Python code, it is permissible to break before or after a binary operator,
# as long as the convention is consistent locally.
# For new code Knuth’s style is suggested

sales = (total
         + total_book
         + total_sales
         - Incomplete
         + rate)

# %%
#  Import : imports is on seperate lines
#  imports are always put on top of file

import datetime
import pandas
import numpy

# %%
#  Source file encoding ?

# %% [markdown]
# # these topics discussed
# identity operator
#
# integer chaching
#
# membership operator
#
# and alot of real world example of real world

# %%
#  Avoid extra whitespaces
# imideatly from inside paranthesis bracktes
val = {"name":"rabia","age":22} # correct
val = { "name" : "rabia" ,"age" : 22 } # wrong way
# Between a trailing comma and a following close parenthesis
val = (8,) # correct
val = (8, ) # wrong

# immediately before comma , semicolon ,colon
if x == 4: print(x, y); x, y = y, x # correct

if x == 4 : print(x , y) ; x , = y ,x #wrong

# Immediately before the open parenthesis that starts the argument
# list of a function call:
spam(9) # correct
spam (9) #wrong

# Immediately before the open parenthesis that starts an indexing or slicing:
 List[2] = lst[index] # correct

 List [2] = lst [index] # wrong


# more than one space arround assignment operator

a = 4   # correct
a    =   6   # wrong

# %% [markdown]
# # **String operation in python**
# `String interning`
# `type casting`
# `operation in string`
# `dir`
# `str built in method`
# `importantance of string in ml and nlp`

# %% [markdown]
# #**Cheat Sheet of python**

# %% [markdown]
# ![](https://i.pinimg.com/736x/aa/87/15/aa8715d2ce970deaa58e286ab4a1a595.jpg)
# # taking it from pintress

# %% [markdown]
# ![](https://i1-c.pinimg.com/1200x/53/ef/60/53ef60325093da938cd996fdad013f7b.jpg)
# ![](https://i.pinimg.com/736x/14/b9/f3/14b9f34418be7d7854afe88fa2273c0a.jpg)
# ![](https://i.pinimg.com/736x/2f/07/dd/2f07dd15a3baf85a8945c23ace0b7a0d.jpg)
